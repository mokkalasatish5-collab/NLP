# %%
import spacy

# %%
nlp = spacy.blank("en")
doc = nlp("Dr. Strange loves pav bhaji of mumbai as it costs only 2$ per plate.")
for token in doc:
    print(token)
# Out:
# Dr.
# Strange
# loves
# pav
# bhaji
# of
# mumbai
# as
# it
# costs
# only
# 2
# $
# per
# plate
# .

# %%
doc[:]
# Out:
# Dr. Strange loves pav bhaji of mumbai as it costs only 2$ per plate.

# %%
type(nlp)
# Out:
# spacy.lang.en.English

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %%
doc = nlp("Tony gave two $ to Peter.")

# %%
token0 = doc[0]
token0
# Out:
# Tony

# %%
token0.is_alpha
# Out:
# True

# %%
token2 = doc[2]
token2
# Out:
# two

# %%
token2.like_num
# Out:
# True

# %%
token3 = doc[3]
token3
# Out:
# $

# %%
token3.like_num
# Out:
# False

# %%
token3.is_currency
# Out:
# True

# %%
for token in doc:
    print(token, "==>", "index: ", token.i, "is_alpha:", token.is_alpha,
          "is_punct:", token.is_punct,
          "like_num:", token.like_num,
          "is_currency:", token.is_currency,
         )
# Out:
# Tony ==> index:  0 is_alpha: True is_punct: False like_num: False is_currency: False
# gave ==> index:  1 is_alpha: True is_punct: False like_num: False is_currency: False
# two ==> index:  2 is_alpha: True is_punct: False like_num: True is_currency: False
# $ ==> index:  3 is_alpha: False is_punct: False like_num: False is_currency: True
# to ==> index:  4 is_alpha: True is_punct: False like_num: False is_currency: False
# Peter ==> index:  5 is_alpha: True is_punct: False like_num: False is_currency: False
# . ==> index:  6 is_alpha: False is_punct: True like_num: False is_currency: False

# %%
with open('students.txt') as f:
    text = f.readlines()
text
# Out:
# ['Dayton high school, 8th grade students information\n',
#  '==================================================\n',
#  '\n',
#  'Name\tbirth day   \temail\n',
#  '-----\t------------\t------\n',
#  'Virat   5 June, 1882    virat@kohli.com\n',
#  'Maria\t12 April, 2001  maria@sharapova.com\n',
#  'Serena  24 June, 1998   serena@williams.com\n',
#  'Joe      1 May, 1997    joe@root.com']

# %%
text = ' '.join(text)
text
# Out:
# 'Dayton high school, 8th grade students information\n ==================================================\n \n Name\tbirth day   \temail\n -----\t------------\t------\n Virat   5 June, 1882    virat@kohli.com\n Maria\t12 April, 2001  maria@sharapova.com\n Serena  24 June, 1998   serena@williams.com\n Joe      1 May, 1997    joe@root.com'

# %%
doc = nlp(text)
email = []
for token in doc:
    if token.like_email:
        email.append(token)

# %%
email
# Out:
# [virat@kohli.com, maria@sharapova.com, serena@williams.com, joe@root.com]

# %% [markdown]
# lets take the nlp in telugu

# %%
nlp = spacy.blank("te")

# %%
doc = nlp("డేటా సైన్స్ లేదా జెన్ AI లో ఉద్యోగం కోసం చూస్తున్నారా ?")
for token in doc:
    print(token)
# Out:
# డేటా
# సైన్స్
# లేదా
# జెన్
# AI
# లో
# ఉద్యోగం
# కోసం
# చూస్తున్నారా
# ?

# %%
doc = nlp("డేటా సైన్స్ లేదా జెన్ ఏఐలో ఉద్యోగం కోసం చూస్తున్నారా, ఆపై satish.mokkala@gmail.com కు మెయిల్ చేయండి.")
for token in doc:
    if token is not None:
        print(token)
# Out:
# డేటా
# సైన్స్
# లేదా
# జెన్
# ఏఐలో
# ఉద్యోగం
# కోసం
# చూస్తున్నారా
# ,
# ఆపై
# satish.mokkala@gmail.com
# కు
# మెయిల్
# చేయండి
# .

# %%
from spacy.symbols import ORTH

nlp = spacy.blank("en")
doc = nlp("gimme double cheese extra large healthy pizza")
tokens = [token.text for token in doc]
tokens
# Out:
# ['gimme', 'double', 'cheese', 'extra', 'large', 'healthy', 'pizza']

# %%
nlp.tokenizer.add_special_case("gimme", [
    {ORTH: "gim"},
    {ORTH: "me"},
])
doc = nlp("gimme double cheese extra large healthy pizza")
tokens = [token.text for token in doc]
tokens
# Out:
# ['gim', 'me', 'double', 'cheese', 'extra', 'large', 'healthy', 'pizza']

# %%
doc = nlp("Dr. Strange loves pav bhaji of mumbai. Hulk loves chat of delhi")
for sentence in doc.sents:
    print(sentence)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 doc = nlp("Dr. Strange loves pav bhaji of mumbai. Hulk loves chat of delhi")
# ----> 2 for sentence in doc.sents:
#       3     print(sentence)
#
# File ~/PycharmProjects/NLP/.venv/lib/python3.13/site-packages/spacy/tokens/doc.pyx:926, in sents()
#
# ValueError: [E030] Sentence boundaries unset. You can add the 'sentencizer' component to the pipeline with: `nlp.add_pipe('sentencizer')`. Alternatively, add the dependency parser or sentence recognizer, or set sentence boundaries by setting `doc[i].is_sent_start`.

# %%
nlp.pipeline
# Out:
# []

# %%
nlp.add_pipe('sentencizer')

# %%
doc = nlp("Dr. Strange loves pav bhaji of mumbai. Hulk loves chat of delhi")
for sentence in doc.sents:
    print(sentence)
# Out:
# Dr. Strange loves pav bhaji of mumbai.
# Hulk loves chat of delhi

# %%
nlp.pipeline
# Out:
# [('sentencizer', <spacy.pipeline.sentencizer.Sentencizer at 0x10604ac50>)]

# %% [markdown]
# EXERCISE

# %%
text='''
Look for data to help you address the question. Governments are good
sources because data from public research is often freely available. Good
places to start include http://www.data.gov/, and http://www.science.
gov/, and in the United Kingdom, http://data.gov.uk/.
Two of my favorite data sets are the General Social Survey at http://www3.norc.org/gss+website/,
and the European Social Survey at http://www.europeansocialsurvey.org/.
'''

# %%
nlp = spacy.blank('en')
text = nlp(text)
email_token = [token for token in text if token.like_url]
print(email_token)
# Out:
# [http://www.data.gov/, http://www.science, http://data.gov.uk/., http://www3.norc.org/gss+website/, http://www.europeansocialsurvey.org/.]

# %%
transactions = nlp("Tony gave two $ to Peter, Bruce gave 500 € to Steve")
for token in transactions:
    if token.like_num and transactions[token.i+1].is_currency:
        print(token,transactions[token.i+1].text)
# Out:
# two $
# 500 €
